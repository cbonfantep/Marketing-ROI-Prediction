# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
## Read one file and adjust 'skiprows'

file = "output.xlsx"
file_avg = pd.read_excel(file)
file_avg.head()
# Out:
#    Unnamed: 0        Day  Site Key  Site Name  Ad Spend  Impressions  Clicks  \
# 0          13 2018-01-01   1504089  QuantCast  862.7850     246510.0    82.0
# 1          34 2018-01-02   1504089  QuantCast  868.4305     248123.0    98.0
# 2          46 2018-01-03   1504089  QuantCast  860.7235     245921.0    66.0
# 3          65 2018-01-04   1504089  QuantCast  867.5030     247858.0    50.0
# 4          91 2018-01-05   1504089  QuantCast  884.5900     252740.0    52.0
#
#    Room Orders  Room Revenue*  Room Nights  Viewable Impressions  \
# 0            2    4440.080357           16              110984.0
# 1            8    5787.517857           21              143263.0
# 2            4    3276.919643           11              145981.0
# 3            8   16711.464286           18              133737.0
# 4            7   13765.607143           21              129017.0
#
#    Ad Spend_Mov Avg  Impressions_Mov Avg  Clicks_Mov Avg  Room Orders_Mov Avg  \
# 0               NaN                  NaN             NaN                  NaN
# 1               NaN                  NaN             NaN                  NaN
# 2               NaN                  NaN             NaN                  NaN
# 3               NaN                  NaN             NaN                  NaN
# 4               NaN                  NaN             NaN                  NaN
#
#    Room Revenue*_Mov Avg  Room Nights_Mov Avg  Viewable Impressions_Mov Avg
# 0                    NaN                  NaN                           NaN
# 1                    NaN                  NaN                           NaN
# 2                    NaN                  NaN                           NaN
# 3                    NaN                  NaN                           NaN
# 4                    NaN                  NaN                           NaN

# %%
## Combine all files via loop and store it as a combined data frame called 'all_data'

# file_list = ["2. A Rooms_Marketing_20180101-20180331.xlsx", "2. A Rooms_Marketing_20180401-20180630.xlsx", \
#              "2. A Rooms_Marketing_20180701-20180930.xlsx", "2. A Rooms_Marketing_20181001-20181231.xlsx", \
#              "2. A Rooms_Marketing_20190101-20190331.xlsx","2. A Rooms_Marketing_20190401-20190630.xlsx", \
#              "2. A Rooms_Marketing_20190701-20190930.xlsx"]


# all_data = pd.DataFrame()

# for file in file_list:
#     df = pd.read_excel(file, skiprows=6)
#     all_data = all_data.append(df, ignore_index=True)

# %%
## Check if it worked and overall stats

file_avg.head()
# file_avg.describe()
# Out:
#    Unnamed: 0        Day  Site Key  Site Name  Ad Spend  Impressions  Clicks  \
# 0          13 2018-01-01   1504089  QuantCast  862.7850     246510.0    82.0
# 1          34 2018-01-02   1504089  QuantCast  868.4305     248123.0    98.0
# 2          46 2018-01-03   1504089  QuantCast  860.7235     245921.0    66.0
# 3          65 2018-01-04   1504089  QuantCast  867.5030     247858.0    50.0
# 4          91 2018-01-05   1504089  QuantCast  884.5900     252740.0    52.0
#
#    Room Orders  Room Revenue*  Room Nights  Viewable Impressions  \
# 0            2    4440.080357           16              110984.0
# 1            8    5787.517857           21              143263.0
# 2            4    3276.919643           11              145981.0
# 3            8   16711.464286           18              133737.0
# 4            7   13765.607143           21              129017.0
#
#    Ad Spend_Mov Avg  Impressions_Mov Avg  Clicks_Mov Avg  Room Orders_Mov Avg  \
# 0               NaN                  NaN             NaN                  NaN
# 1               NaN                  NaN             NaN                  NaN
# 2               NaN                  NaN             NaN                  NaN
# 3               NaN                  NaN             NaN                  NaN
# 4               NaN                  NaN             NaN                  NaN
#
#    Room Revenue*_Mov Avg  Room Nights_Mov Avg  Viewable Impressions_Mov Avg
# 0                    NaN                  NaN                           NaN
# 1                    NaN                  NaN                           NaN
# 2                    NaN                  NaN                           NaN
# 3                    NaN                  NaN                           NaN
# 4                    NaN                  NaN                           NaN

# %%
# Looking for null values

file_avg.isna().head()
# Out:
#    Unnamed: 0    Day  Site Key  Site Name  Ad Spend  Impressions  Clicks  \
# 0       False  False     False      False     False        False   False
# 1       False  False     False      False     False        False   False
# 2       False  False     False      False     False        False   False
# 3       False  False     False      False     False        False   False
# 4       False  False     False      False     False        False   False
#
#    Room Orders  Room Revenue*  Room Nights  Viewable Impressions  \
# 0        False          False        False                 False
# 1        False          False        False                 False
# 2        False          False        False                 False
# 3        False          False        False                 False
# 4        False          False        False                 False
#
#    Ad Spend_Mov Avg  Impressions_Mov Avg  Clicks_Mov Avg  Room Orders_Mov Avg  \
# 0              True                 True            True                 True
# 1              True                 True            True                 True
# 2              True                 True            True                 True
# 3              True                 True            True                 True
# 4              True                 True            True                 True
#
#    Room Revenue*_Mov Avg  Room Nights_Mov Avg  Viewable Impressions_Mov Avg
# 0                   True                 True                          True
# 1                   True                 True                          True
# 2                   True                 True                          True
# 3                   True                 True                          True
# 4                   True                 True                          True

# %%
## Dropped Null values from ad spend and revenue column as a start

clean_simple_df = all_data.dropna(subset=['Ad Spend', 'Room Revenue*'])

clean_simple_df.isna().head()
# Out:
#      Day  Site Key  Site Name  Ad Spend  Impressions  Clicks  Room Orders  \
# 0  False     False      False     False        False   False        False
# 1  False     False      False     False        False   False        False
# 2  False     False      False     False        False   False        False
# 3  False     False      False     False        False   False        False
# 4  False     False      False     False         True    True        False
#
#    Room Revenue*  Room Nights  Measurable Impressions  Viewable Impressions
# 0          False        False                    True                  True
# 1          False        False                   False                 False
# 2          False        False                   False                 False
# 3          False        False                    True                  True
# 4          False        False                    True                  True

# %%
# X = all_data["weight"].values.reshape(-1, 1)
# y = all_data["size"].values.reshape(-1, 1)


X = clean_simple_df["Ad Spend"].values.reshape(-1, 1)
y = clean_simple_df["Room Revenue*"].values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (17667, 1) (17667, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

model = LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 75126894.38844147
# R-squared (R2 ): 0.5266723965102784

# %%
model.score(X, y)
# Out:
# 0.5288285293913064

# %%
model.score(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.5266723965102784

# %%
plt.scatter(X, y)
