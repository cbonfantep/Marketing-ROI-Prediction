# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
## Read one file and adjust 'skiprows'

file = "output1.xlsx"
file_avg = pd.read_excel(file)
file_avg.head()
# Out:
#          Day  Site Key       Site Name     Ad Spend  Impressions  Clicks  \
# 0 2018-01-31   2761561  Google AdWords  8440.200000      68590.0  2941.0
# 1 2018-01-31   1556720  www.sojern.com  4436.770000     887354.0   467.0
# 2 2018-01-31   1506491     Adara Media  2893.200645     299496.0    30.0
# 3 2018-01-31   1506505     TripAdvisor  2384.538000      91713.0    44.0
# 4 2018-01-31   2810812        Bing Ads  2122.820000      24091.0   735.0
#
#    Room Orders  Room Revenue*  Room Nights  Measurable Impressions  \
# 0           56   62174.357143          186                     NaN
# 1           17   24563.160714           66                873600.0
# 2            3    2824.401786            8                288742.0
# 3            8    6532.580357           20                 86825.0
# 4           14   10566.758929           37                     NaN
#
#    Viewable Impressions  Ad Spend_avg  Impressions_avg   Clicks_avg  \
# 0                   NaN  16710.325806     91059.870968  3548.161290
# 1              485920.0   3890.311935    778063.032258   431.774194
# 2               66107.0   3225.807258    343843.548387   117.935484
# 3               63637.0   2721.513935    104673.612903    77.129032
# 4                   NaN   2589.757742     26775.645161   761.741935
#
#    Room Orders_avg  Room Revenue*_avg  Room Nights_avg  \
# 0        58.741935       60025.879608       176.290323
# 1        16.225806       19018.430876        53.096774
# 2         7.322581        8062.751728        21.161290
# 3         7.967742        6828.093894        21.516129
# 4         8.741935        8995.154666        26.806452
#
#    Measurable Impressions_avg  Viewable Impressions_avg
# 0                         NaN                       NaN
# 1               767137.935484             437188.741935
# 2               345675.033333             168323.866667
# 3               101060.870968              74513.193548
# 4                         NaN                       NaN

# %%
## Combine all files via loop and store it as a combined data frame called 'all_data'

# file_list = ["2. A Rooms_Marketing_20180101-20180331.xlsx", "2. A Rooms_Marketing_20180401-20180630.xlsx", \
#              "2. A Rooms_Marketing_20180701-20180930.xlsx", "2. A Rooms_Marketing_20181001-20181231.xlsx", \
#              "2. A Rooms_Marketing_20190101-20190331.xlsx","2. A Rooms_Marketing_20190401-20190630.xlsx", \
#              "2. A Rooms_Marketing_20190701-20190930.xlsx"]


# all_data = pd.DataFrame()

# for file in file_list:
#     df = pd.read_excel(file, skiprows=6)
#     all_data = all_data.append(df, ignore_index=True)

# %%
## Check if it worked and overall stats

file_avg.head()
# file_avg.describe()
# Out:
#          Day  Site Key       Site Name     Ad Spend  Impressions  Clicks  \
# 0 2018-01-31   2761561  Google AdWords  8440.200000      68590.0  2941.0
# 1 2018-01-31   1556720  www.sojern.com  4436.770000     887354.0   467.0
# 2 2018-01-31   1506491     Adara Media  2893.200645     299496.0    30.0
# 3 2018-01-31   1506505     TripAdvisor  2384.538000      91713.0    44.0
# 4 2018-01-31   2810812        Bing Ads  2122.820000      24091.0   735.0
#
#    Room Orders  Room Revenue*  Room Nights  Measurable Impressions  \
# 0           56   62174.357143          186                     NaN
# 1           17   24563.160714           66                873600.0
# 2            3    2824.401786            8                288742.0
# 3            8    6532.580357           20                 86825.0
# 4           14   10566.758929           37                     NaN
#
#    Viewable Impressions  Ad Spend_avg  Impressions_avg   Clicks_avg  \
# 0                   NaN  16710.325806     91059.870968  3548.161290
# 1              485920.0   3890.311935    778063.032258   431.774194
# 2               66107.0   3225.807258    343843.548387   117.935484
# 3               63637.0   2721.513935    104673.612903    77.129032
# 4                   NaN   2589.757742     26775.645161   761.741935
#
#    Room Orders_avg  Room Revenue*_avg  Room Nights_avg  \
# 0        58.741935       60025.879608       176.290323
# 1        16.225806       19018.430876        53.096774
# 2         7.322581        8062.751728        21.161290
# 3         7.967742        6828.093894        21.516129
# 4         8.741935        8995.154666        26.806452
#
#    Measurable Impressions_avg  Viewable Impressions_avg
# 0                         NaN                       NaN
# 1               767137.935484             437188.741935
# 2               345675.033333             168323.866667
# 3               101060.870968              74513.193548
# 4                         NaN                       NaN

# %%
# Looking for null values

file_avg.isna().head()
# Out:
#      Day  Site Key  Site Name  Ad Spend  Impressions  Clicks  Room Orders  \
# 0  False     False      False     False        False   False        False
# 1  False     False      False     False        False   False        False
# 2  False     False      False     False        False   False        False
# 3  False     False      False     False        False   False        False
# 4  False     False      False     False        False   False        False
#
#    Room Revenue*  Room Nights  Measurable Impressions  Viewable Impressions  \
# 0          False        False                    True                  True
# 1          False        False                   False                 False
# 2          False        False                   False                 False
# 3          False        False                   False                 False
# 4          False        False                    True                  True
#
#    Ad Spend_avg  Impressions_avg  Clicks_avg  Room Orders_avg  \
# 0         False            False       False            False
# 1         False            False       False            False
# 2         False            False       False            False
# 3         False            False       False            False
# 4         False            False       False            False
#
#    Room Revenue*_avg  Room Nights_avg  Measurable Impressions_avg  \
# 0              False            False                        True
# 1              False            False                       False
# 2              False            False                       False
# 3              False            False                       False
# 4              False            False                        True
#
#    Viewable Impressions_avg
# 0                      True
# 1                     False
# 2                     False
# 3                     False
# 4                      True

# %%
## Dropped Null values from ad spend and revenue column as a start

# clean_simple_df = all_data.dropna(subset=['Ad Spend', 'Room Revenue*'])

# clean_simple_df.isna().head()

# %%
# X = all_data["weight"].values.reshape(-1, 1)
# y = all_data["size"].values.reshape(-1, 1)


X = file_avg[["Ad Spend_avg", "Impressions_avg", "Clicks_avg"]]
y = file_avg["Room Revenue*_avg"].values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (10923, 3) (10923, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

model = LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 0.0
# R-squared (R2 ): 1.0

# %%
model.score(X, y)
# Out:
# 1.0

# %%
model.score(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 1.0

# %%
partner_list = file_avg['Site Name'].unique()
partner_list
# Out:
# array(['Google AdWords', 'www.sojern.com', 'Adara Media', 'TripAdvisor',
#        'Bing Ads', 'The Trade Desk', 'kayak.com', 'QuantCast',
#        'DoubleClick BidManager', 'smartervegas.com', 'Yahoo Gemini',
#        'yelp.com', 'Expedia', 'Instagram', 'Expedia ATD', 'Facebook',
#        'united.com', 'Turn, Inc.', 'Oath.com', 'Q1 Media',
#        'Conde Nast Traveler', 'Martini Media Network', 'Pinterest ATD'],
#       dtype=object)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler

import pickle
from joblib import dump, load

final_model = []
r_squared = []
r_df_dict = {'Site': [], 'ModelName':[], 'Score': [], 'Number': []}

def append_record(table, site, model_name, score, num_rec):
    table['Site'].append(site)
    table['ModelName'].append(model_name)
    table['Score'].append(score)    
    table['Number'].append(num_rec)    

for partner in partner_list:
    
    
## Simple Linear
    
    df = file_avg[file_avg['Site Name']==partner]
    
    X = df["Ad Spend_avg"].values.reshape(-1, 1)
    y = df["Room Revenue*_avg"].values.reshape(-1, 1)   
    
    model = LinearRegression()
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    model.fit(X_train, y_train)
    
    # Use our model to make predictions
    predicted = model.predict(X_test)

    # Score the predictions with mse and r2
    mse = mean_squared_error(y_test, predicted)
    r2 = r2_score(y_test, predicted)

#     print(f"{partner} Mean Squared Error (MSE): {mse}")
#     print(f" {partner} R-squared (R2 ): {r2}")

    append_record(r_df_dict, partner, 'Linear', r2, len(df))
   

    ## Multivariate Linear 
    
    df = file_avg[file_avg['Site Name']==partner]
    
    X = df[["Ad Spend_avg", "Impressions_avg", "Clicks_avg"]]
    y = df["Room Revenue*_avg"].values.reshape(-1, 1)   
    
    model = LinearRegression()
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    model.fit(X_train, y_train)
    
    # Use our model to make predictions
    predicted = model.predict(X_test)

    # Score the predictions with mse and r2
    mse = mean_squared_error(y_test, predicted)
    r2 = r2_score(y_test, predicted)
    
    append_record(r_df_dict, partner, 'Multivariate Linear', r2, len(df))
    
#     print(f"{partner} Mean Squared Error (MSE): {mse}")
#     print(f" {partner} R-squared (R2 ): {r2}")
    
    
    # Scaler
    
# Create a StandardScater model and fit it to the training data
    
    X_scaler = StandardScaler().fit(X_train)
    y_scaler = StandardScaler().fit(y_train)
    

# Transform the training and testing data using the X_scaler and y_scaler models    
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    y_train_scaled = y_scaler.transform(y_train)
    y_test_scaled = y_scaler.transform(y_test)


 ### LASSO
    
    
    lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

    predictions = lasso.predict(X_test_scaled)

    MSE = mean_squared_error(y_test_scaled, predictions)
    r2 = lasso.score(X_test_scaled, y_test_scaled)

    append_record(r_df_dict, partner, 'Lasso', r2, len(df))
    
#     print(f"MSE: {MSE}, R2: {r2}")   
    
    
    
    
### Ridge
    ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)
#     print(f"ridge={type(ridge)}")

    predictions = ridge.predict(X_test_scaled)

    MSE = mean_squared_error(y_test_scaled, predictions)
    r2 = r2_score(y_test_scaled, predictions)

    append_record(r_df_dict, partner, 'Ridge', r2, len(df))

    # print(f"MSE: {MSE}, R2: {r2}")    
    
    
    
### ElasticNet
    elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

    predictions = elasticnet.predict(X_test_scaled)

    MSE = mean_squared_error(y_test_scaled, predictions)
    r2 = r2_score(y_test_scaled, predictions)

#     print(f"MSE: {MSE}, R2: {r2}")
    
    append_record(r_df_dict, partner, 'ElasticNet', r2, len(df))
    
    # Uncomment and adjustif want to save the model
#     s = pickle.dumps(model)
#     dump(s, f"multi_linear_{partner}.joblib")

r_df = pd.DataFrame(r_df_dict)

# %%
r_squared
# Out:
# []

# %%
r_df
# Out:
#                       Site            ModelName     Score  Number
# 0           Google AdWords               Linear  0.078795     601
# 1           Google AdWords  Multivariate Linear  0.587148     601
# 2           Google AdWords                Lasso  0.574955     601
# 3           Google AdWords                Ridge  0.587124     601
# 4           Google AdWords           ElasticNet  0.575491     601
# 5           www.sojern.com               Linear  0.057953     603
# 6           www.sojern.com  Multivariate Linear  0.141420     603
# 7           www.sojern.com                Lasso  0.087508     603
# 8           www.sojern.com                Ridge  0.139060     603
# 9           www.sojern.com           ElasticNet  0.088546     603
# 10             Adara Media               Linear  0.115092     604
# 11             Adara Media  Multivariate Linear  0.473223     604
# 12             Adara Media                Lasso  0.496650     604
# 13             Adara Media                Ridge  0.473344     604
# 14             Adara Media           ElasticNet  0.496523     604
# 15             TripAdvisor               Linear  0.437286     599
# 16             TripAdvisor  Multivariate Linear  0.755956     599
# 17             TripAdvisor                Lasso  0.748920     599
# 18             TripAdvisor                Ridge  0.755942     599
# 19             TripAdvisor           ElasticNet  0.746919     599
# 20                Bing Ads               Linear  0.057070     601
# 21                Bing Ads  Multivariate Linear  0.408564     601
# 22                Bing Ads                Lasso  0.400773     601
# 23                Bing Ads                Ridge  0.408555     601
# 24                Bing Ads           ElasticNet  0.402498     601
# 25          The Trade Desk               Linear -0.005330     600
# 26          The Trade Desk  Multivariate Linear  0.399144     600
# 27          The Trade Desk                Lasso  0.392239     600
# 28          The Trade Desk                Ridge  0.399138     600
# 29          The Trade Desk           ElasticNet  0.393614     600
# ..                     ...                  ...       ...     ...
# 85              Turn, Inc.               Linear  0.121572     132
# 86              Turn, Inc.  Multivariate Linear  0.391505     132
# 87              Turn, Inc.                Lasso  0.384139     132
# 88              Turn, Inc.                Ridge  0.391465     132
# 89              Turn, Inc.           ElasticNet  0.385756     132
# 90                Oath.com               Linear -0.033757     450
# 91                Oath.com  Multivariate Linear  0.506050     450
# 92                Oath.com                Lasso  0.512665     450
# 93                Oath.com                Ridge  0.506058     450
# 94                Oath.com           ElasticNet  0.510902     450
# 95                Q1 Media               Linear  0.528344     296
# 96                Q1 Media  Multivariate Linear  0.660474     296
# 97                Q1 Media                Lasso  0.666793     296
# 98                Q1 Media                Ridge  0.660495     296
# 99                Q1 Media           ElasticNet  0.664987     296
# 100    Conde Nast Traveler               Linear  0.829805     287
# 101    Conde Nast Traveler  Multivariate Linear  0.864463     287
# 102    Conde Nast Traveler                Lasso  0.875822     287
# 103    Conde Nast Traveler                Ridge  0.864640     287
# 104    Conde Nast Traveler           ElasticNet  0.876689     287
# 105  Martini Media Network               Linear  0.296572     241
# 106  Martini Media Network  Multivariate Linear  0.341250     241
# 107  Martini Media Network                Lasso  0.317557     241
# 108  Martini Media Network                Ridge  0.340820     241
# 109  Martini Media Network           ElasticNet  0.319963     241
# 110          Pinterest ATD               Linear  1.000000      50
# 111          Pinterest ATD  Multivariate Linear  1.000000      50
# 112          Pinterest ATD                Lasso  1.000000      50
# 113          Pinterest ATD                Ridge  1.000000      50
# 114          Pinterest ATD           ElasticNet  1.000000      50
#
# [115 rows x 4 columns]

# %%
best_model = r_df.groupby('Site').max('Score')
best_model
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-5a7b016ffeef> in <module>
# ----> 1 best_model = r_df.groupby('Site').max('Score')
#       2 best_model
#
# TypeError: f() takes 1 positional argument but 2 were given
